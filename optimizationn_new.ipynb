# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav05082002/collab-notebooks/blob/main/optimizationn_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date, timedelta
import time
import threading

# List of table names
table_names =  ['1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4']
previous_days = 1

def factorial(n):
    time.sleep(0)

def process_table(table_name):
    # factorial(100000)
    print(table_name)

start_time = time.time()
threads = []

# Create threads for each table name and start them
for table_name in table_names:
    for day_to_add in range(previous_days + 1):
        thr = threading.Thread(target=process_table, args=(table_name,))
        threads.append(thr)
        thr.start()

# Wait for all threads to complete
for thr in threads:
    thr.join()

end_time = time.time()
elapsed_time_ms = (end_time - start_time) * 1000

print(f"Elapsed time: {elapsed_time_ms} milliseconds")
# Out:
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd44ddddd4
#
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc34ddddd4
#
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa11aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
#
# 2bbbbbbbbbbbbbbbbbbbbb22bbbbbbbbbbbbbbbbbbbbb2
#
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd4
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd44ddddd4
#
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd4
# 4ddddd41aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
#
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# ...

# %%
from datetime import date, timedelta
import time
import concurrent.futures

# List of table names
table_names = ['1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4','1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1', '2bbbbbbbbbbbbbbbbbbbbb2', '3ccccccccc3', '4ddddd4']
previous_days = 1

def factorial(n):
    time.sleep(0)

def process_table(table_name):
    # factorial(100000)
    print(table_name)

start_time = time.time()

if __name__ == '__main__':
    worker_threads = 4  # Number of worker threads
    with concurrent.futures.ThreadPoolExecutor(max_workers=worker_threads) as executor:
        futures = []
        for table_name in table_names:
            for day_to_add in range(previous_days + 1):
                futures.append(executor.submit(process_table, table_name))

        # Wait for all futures to complete
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # Ensure all tasks complete and handle exceptions if any
            except Exception as e:
                print(f'Error processing task: {e}')

end_time = time.time()
elapsed_time_ms = (end_time - start_time) * 1000

print(f"Elapsed time: {elapsed_time_ms} milliseconds")
# Out:
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd4
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa12bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd4
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc33ccccccccc3
# 4ddddd4
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd4
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# 3ccccccccc3
# 4ddddd4
# 4ddddd4
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 1aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa1
# 2bbbbbbbbbbbbbbbbbbbbb2
# 2bbbbbbbbbbbbbbbbbbbbb2
# 3ccccccccc3
# ...
